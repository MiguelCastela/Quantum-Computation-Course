# %% [markdown]
# Inf. e Comp. Quânticas 1a Avaliação para Casa Nov. 2024
#
# ---
#
# #  2ª Avaliação para casa <a id="ex1"></a>
#
# Envie um pequeno relatório em PDF e código com respostas aos exercícios seguintes e às suas execuções no simulador com ruído e em hardware real da IBM para os algoritmos Deutsch-Jozsa e Grover.
#
# Algumas das respostas aos exercícios podem ser escritas à mão ou desenhadas por si, e dos notebooks em python podem imprimir para pdf e juntar num documento único em pdf, mas devem também anexar o código python.
#
#
# ### 2.1 Exercícios simples 1 <a id="ex1"></a>
#
# 1.	Escrever o produto Kronecker (produto tensorial) dos qubits:
#     a)	$|0\rangle\otimes|1\rangle$
#     b)	$|0\rangle\otimes|+\rangle$
#     c)	$|+\rangle\otimes|1\rangle$
#     d)	$|-\rangle\otimes|+\rangle$
#
#  tendo em conta que:
#
# $$ |+\rangle = \tfrac{1}{\sqrt{2}}(|0\rangle + |1\rangle) = \tfrac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ 1 \end{bmatrix}$$
# $$ |-\rangle = \tfrac{1}{\sqrt{2}}(|0\rangle - |1\rangle) = \tfrac{1}{\sqrt{2}}\begin{bmatrix} 1 \\ -1 \end{bmatrix} $$
#
#
#
#
# 2.	Escreva o estado:
#     $|\psi\rangle = \tfrac{1}{\sqrt{2}}|00\rangle + \tfrac{i}{\sqrt{2}}|01\rangle $
#     como doiws qubits perarados.
#
# ### 2.2 Exercícios simples 2 <a id="ex2"></a>
#
# 1. Calcule a unitária ($U$) de um circuito de um quibit  criado pela sequência de portas: $U = XZH$. Utilize o Qiskit para verificar os seus resultados.
#
# 2. Considere um circuito diferente com as mesmas portas, mas "empilhadas" para ter um circuito com 3 qubits, aplicando cada porta a um qubit diferente.
# Calcule o seu produto kronecker (produto tensorial) para obter a unitária ($U$) do circuito de 3 quibits, em seguida, verifique a sua resposta utilizando o Qiskit.
#
# **Nota:** Diferentes livros, software e sites ordenam os seus qubits de forma diferente. Isto significa que o produto Kronecker do mesmo circuito pode parecer muito diferente. Tente ter isto em mente quando consultar outras fontes.
#
# ### Exercícios simples 3 <a id="ex3"></a>
# 1. Crie um circuito quântico que produza o estado de Bell: $\tfrac{1}{\sqrt{2}}(|01\rangle + |10\rangle)$.
#    Utilize o Qiskit para construir o circuito e statevector para verificar o seu resultado.
#
# 2. O circuito que criou acima transforma o estado $|00\rangle$ em $\tfrac{1}{\sqrt{2}}(|01\rangle + |10\rangle)$, calcule a matriz unitária deste circuito utilizando o Qiskit. Verifique se esta unitária realiza de facto a transformação correta.
#
#
# ### 2.4 Algoritmo Deutsch-Jozsa <a id="ex4"></a>
#
# Apresente a sua implementação, simulação de alguns casos, e execução em hardware real de pelo menos dois casos aproventando o número de qubits disponiveis.
#
# ### 2.5 Grover's Algorithm <a id="ex5"></a>
#
# Apresente a sua implementação, simulação de alguns casos, e execução em hardware real de pelo menos dois casos aproventando o número de qubits disponiveis.
#
#
# ## Submeter o trabalho no inforestudante.
#
# https://inforestudante.uc.pt/
#
#
#
#
#
#
#
#
#
# -------------------------
#
# -------------------------
# Jorge Lobo, Novembro 2024
#
# Para a realização do trabaho deve ter em conta os notebooks parilhados nas aulas laboratoriais:
#
# jlobo2024_why_quantum_computing.ipynb
#
# jlobo2024_atoms_of_computation.ipynb
#
# jlobo2024_multiple_qubits_entangled_states.ipynb
#
# jlobo2024_phase_kickback.ipynb
#
# jlobo2024_deutsch_jozsa.ipynb
#
# Links úteis de https://learning.quantum.ibm.com/:
#
# <a href="https://learning.quantum.ibm.com/course/basics-of-quantum-information/single-systems"> Single systems <a>
#
# <a href="https://learning.quantum.ibm.com/course/basics-of-quantum-information/multiple-systems"> Multiple systems </a>
#
# <a href="https://learning.quantum.ibm.com/course/basics-of-quantum-information/quantum-circuits"> Quantum circuits
#  </a>
#
# <a href="https://learning.quantum.ibm.com/course/fundamentals-of-quantum-algorithms/quantum-query-algorithms"> Quantum query algorithms - The Deutsch-Jozsa algorithm
# </a>
#
# <a href="https://learning.quantum.ibm.com/course/fundamentals-of-quantum-algorithms/grovers-algorithm"> Grover's algorithm
# </a>
