# %% [markdown]
# Jorge Lobo, October 2024
#
# References:
#
# Qiskit textbook  https://github.com/Qiskit/textbook *
#
# You can open the files from github in colab with this webpage: https://openincolab.com/ *
#
# (*) embeded code is outdated, check IBM learning for up to date code (https://learning.quantum.ibm.com/)
#
# ### 1.1 Why quantum computing?
# <a target="_blank" href="https://colab.research.google.com/github/Qiskit/textbook/blob/main/notebooks/intro/why-quantum-computing.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# ### 1.2 The atoms of computation
# <a target="_blank" href="https://colab.research.google.com/github/Qiskit/textbook/blob/main/notebooks/intro/atoms-of-computation.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
#
#
#
# ### 2.2 Multiple Qubits and Entangled States <a target="_blank" href="https://colab.research.google.com/github/Qiskit/textbook/blob/main/notebooks/ch-gates/multiple-qubits-entangled-states.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# ### 3.2 Deutsch-Jozsa Algorithm <a target="_blank" href="https://colab.research.google.com/github/Qiskit/textbook/blob/main/notebooks/ch-algorithms/deutsch-jozsa.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
#
# ### 3.8 Grover’s Algorithm <a target="_blank" href="https://colab.research.google.com/github/Qiskit/textbook/blob/main/notebooks/ch-algorithms/grover.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
#
# ## Unitaries, statevectors, density matrices, ... from the new module AerSimulator?
#
# <a href="https://quantumcomputing.stackexchange.com/questions/37236/how-to-get-unitaries-statevectors-density-matrices-and-everything-else-from-t">How to get unitaries, statevectors, density matrices, and everything else from the new module AerSimulator?</a>
